# %% [markdown]
# # Cosas a limpiar
#
# - ** Age ** -> Tiene 5120 nulos. El número es float, para la edad del cliente no es necesario
# - ** job ** -> Tiene 345 nulos. CAmbiar admin. por administrative
# - ** marital ** -> Esta en mayúsculas cambiar a minúsculas
# - ** eduction ** -> Tiene 1807 nulos. Hay puntos separando las palabras cambiar '.' por '_'.
# - ** default ** -> Tiene 8981 nulos. Los valores tienen que ser 1 o 0, por lo que podemos cambiarlo de float a integer.
# - ** housing ** -> Tiene 1026 nulos. Los valores tienen que ser 1 o 0, por lo que podemos cambiarlo de float a integer.
# - ** loan ** -> Tiene 1026 nulos. Los valores tienen que ser 1 o 0, por lo que podemos cambiarlo de float a integer.
# - ** cons.price.idx ** -> Tiene 471 nulos. Cambiar a tipo float cambiando ',' por '.'.
# - ** cons.conf.idx ** -> Cambiar a tipo float cambiando ',' por '.'.
# - ** euribor3m ** -> Tiene 9256 nulos. Cambiar a tipo float cambiando ',' por '.'.
# - ** nr.employed ** -> Cambiar a tipo integer quitando las ','.
# - ** date ** -> Tiene 248 nulos. Cambiar a tipo fecha.

# %%
# Tratamiento de datos
import pandas as pd
pd.set_option('display.max_columns', None)
#----------------

# %%
df_raw = pd.read_csv('../data/bank-additional.csv')
df_raw.sample(5)
# Out:
#        Unnamed: 0   age         job   marital          education  default  \
# 42906       26865  31.0      admin.    SINGLE  university.degree      0.0
# 23957       24079  39.0  management   MARRIED  university.degree      0.0
# 32907       33051  33.0    services    SINGLE        high.school      0.0
# 14520       14617  52.0   housemaid   MARRIED           basic.4y      0.0
# 25104       25226  54.0      admin.  DIVORCED  university.degree      0.0
#
#        housing  loan    contact  duration  campaign  pdays  previous  \
# 42906      0.0   1.0   cellular       264         1    999         0
# 23957      1.0   0.0  telephone       204         1    999         0
# 32907      0.0   0.0   cellular       503         3    999         1
# 14520      1.0   1.0   cellular       105         7    999         0
# 25104      1.0   1.0   cellular       355         2    999         0
#
#           poutcome  emp.var.rate cons.price.idx cons.conf.idx euribor3m  \
# ...

# %%
df = df_raw.copy()

# %% [markdown]
# ### Cambios nombres columnas

# %%
df.columns = df.columns.str.replace('.','_')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'job', 'marital', 'education', 'default',
#        'housing', 'loan', 'contact', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx',
#        'cons_conf_idx', 'euribor3m', 'nr_employed', 'y', 'date', 'latitude',
#        'longitude', 'id_'],
#       dtype='object')

# %% [markdown]
# ### date cambiar a formato fecha

# %%
meses = {
    'enero': 'January',
    'febrero': 'February',
    'marzo': 'March',
    'abril': 'April',
    'mayo': 'May',
    'junio': 'June',
    'julio': 'July',
    'agosto': 'August',
    'septiembre': 'September',
    'octubre': 'October',
    'noviembre': 'November',
    'diciembre': 'December'
}

df['date'] = df['date'].str.lower().replace(meses, regex=True)
df['date'] = pd.to_datetime(df['date'], format='%d-%B-%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      43000 non-null  int64
#  1   age             37880 non-null  float64
#  2   job             42655 non-null  object
#  3   marital         42915 non-null  object
#  4   education       41193 non-null  object
#  5   default         34019 non-null  float64
#  6   housing         41974 non-null  float64
#  7   loan            41974 non-null  float64
#  8   contact         43000 non-null  object
#  9   duration        43000 non-null  int64
#  10  campaign        43000 non-null  int64
#  11  pdays           43000 non-null  int64
#  12  previous        43000 non-null  int64
#  13  poutcome        43000 non-null  object
#  14  emp_var_rate    43000 non-null  float64
#  15  cons_price_idx  42529 non-null  object
#  16  cons_conf_idx   43000 non-null  object
# ...

# %% [markdown]
# ### marital-> Esta en mayúsculas cambiar a minúsculas

# %%
df['marital'] = df['marital'].str.lower()

# %% [markdown]
# ### job-> Cambiar admin. por administrative

# %%
df['job'] = df['job'].str.replace('admin.', 'administrative')

# %% [markdown]
# ### eduction -> Hay puntos separando las palabras cambiar '.' por '_'.

# %%
df['education']= df['education'].str.replace('.', '_')

# %% [markdown]
# ### cons.price.idx -> Cambiar cambiar ',' por '.' y pasar a tipo float
# ### cons.conf.idx -> Cambiar cambiar ',' por '.' y pasar a tipo float
# ### euribor3m -> Cambiar cambiar ',' por '.' y pasar a tipo float

# %%
def comas (df, col):
    df[col] = df[col].str.replace(',', '.')
    df[col] = df[col].astype('float64')

# %%
comas(df,'cons_conf_idx')

# %% [markdown]
# ### Age -> El número es float, para la edad del cliente no es necesario

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce')

# %%
df['age'] = df['age'].astype('Int64')

# %% [markdown]
# ###  nr_employed -> Cambiar a tipo integer quitando las ','.

# %%
df['nr_employed'] = pd.to_numeric(df['nr_employed'], errors='coerce')

# %%
df['nr_employed'] = df['nr_employed'].round(0).astype('Int64')

# %% [markdown]
# ### default -> Los valores tienen que ser 1 o 0, por lo que podemos cambiarlo de float a integer.
# ### housing -> Los valores tienen que ser 1 o 0, por lo que podemos cambiarlo de float a integer.
# ### loan -> Los valores tienen que ser 1 o 0, por lo que podemos cambiarlo de float a integer.

# %%
def enteros(df, col):
    df[col] = pd.to_numeric(df[col], errors='coerce')
    df[col] = df[col].astype('Int64')

# %%
enteros (df, 'default')
enteros (df, 'housing')
enteros (df, 'loan')
# Out:
#        Unnamed: 0   age             job  marital            education  \
# 0               0  <NA>       housemaid  married             basic_4y
# 1               1    57        services  married          high_school
# 2               2    37        services  married          high_school
# 3               3    40  administrative  married             basic_6y
# 4               4    56        services  married          high_school
# ...           ...   ...             ...      ...                  ...
# 42995       19154  <NA>  administrative  married    university_degree
# 42996       26206    34      technician  married  professional_course
# 42997       15046  <NA>     blue-collar   single             basic_6y
# 42998       15280  <NA>  administrative  married    university_degree
# 42999       27570  <NA>      unemployed   single    university_degree
#
#        default  housing  loan    contact  duration  campaign  pdays  previous  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      43000 non-null  int64
#  1   age             37880 non-null  Int64
#  2   job             42655 non-null  object
#  3   marital         42915 non-null  object
#  4   education       41193 non-null  object
#  5   default         34019 non-null  Int64
#  6   housing         41974 non-null  Int64
#  7   loan            41974 non-null  Int64
#  8   contact         43000 non-null  object
#  9   duration        43000 non-null  int64
#  10  campaign        43000 non-null  int64
#  11  pdays           43000 non-null  int64
#  12  previous        43000 non-null  int64
#  13  poutcome        43000 non-null  object
#  14  emp_var_rate    43000 non-null  float64
#  15  cons_price_idx  42529 non-null  float64
#  16  cons_conf_idx   43000 non-null  float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      43000 non-null  int64
#  1   age             37880 non-null  Int64
#  2   job             42655 non-null  object
#  3   marital         42915 non-null  object
#  4   education       41193 non-null  object
#  5   default         34019 non-null  Int64
#  6   housing         41974 non-null  Int64
#  7   loan            41974 non-null  Int64
#  8   contact         43000 non-null  object
#  9   duration        43000 non-null  int64
#  10  campaign        43000 non-null  int64
#  11  pdays           43000 non-null  int64
#  12  previous        43000 non-null  int64
#  13  poutcome        43000 non-null  object
#  14  emp_var_rate    43000 non-null  float64
#  15  cons_price_idx  42529 non-null  float64
#  16  cons_conf_idx   43000 non-null  float64
# ...

# %%
df.to_csv('../data/data_limpios.csv')
