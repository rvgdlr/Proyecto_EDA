# %% [markdown]
# # Cosas a limpiar
#
# - ** Age ** -> Tiene nulos. El número es float, para la edad del cliente no es necesario
# - ** job ** -> Tiene nulos.
# - ** marital ** -> Esta en mayúsculas cambiar a minúsculas
# - ** eduction ** -> Tiene nulos. Hay puntos separando las palabras cambiar '.' por ' '.
# - ** default ** -> Tiene nulos. Los valores tienen que ser 1 o 0, por lo que podemos cambiarlo de float a integer.
# - ** housing ** -> Tiene nulos. Los valores tienen que ser 1 o 0, por lo que podemos cambiarlo de float a integer.
# - ** loan ** -> Tiene nulos. Los valores tienen que ser 1 o 0, por lo que podemos cambiarlo de float a integer.
# - ** cons.price.idx ** -> Tiene nulos. Cambiar a tipo float cambiando ',' por '.'.
# - ** cons.conf.idx ** -> Cambiar a tipo float cambiando ',' por '.'.
# - ** euribor3m ** -> Tiene nulos. Cambiar a tipo float cambiando ',' por '.'.
# - ** nr.employed ** -> Cambiar a tipo integer quitando las ','.
# - ** date ** -> Cambiar a tipo fecha.
